# %%
import numpy as np   
import pandas as pd
import os

import seaborn as sns
import matplotlib.pyplot as plt   
import matplotlib.style
plt.style.use('classic')

import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
# from imblearn.over_sampling import RandomOverSampler   
# from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
# from imblearn.over_sampling import SMOTE,ADASYN

# %%
df=pd.read_csv("German Credit Dataset.csv")

# %%
df.head()
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0           < 0 DM                     6       critical  furniture/appliances
# 1       1 - 200 DM                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
# 3           < 0 DM                    42           good  furniture/appliances
# 4           < 0 DM                    24           poor                   car
#
#    amount savings_balance employment_duration  percent_of_income  \
# 0    1169         unknown           > 7 years                  4
# 1    5951        < 100 DM         1 - 4 years                  2
# 2    2096        < 100 DM         4 - 7 years                  2
# 3    7882        < 100 DM         4 - 7 years                  2
# 4    4870        < 100 DM         1 - 4 years                  3
#
#    years_at_residence  age other_credit housing  existing_loans_count  \
# 0                   4   67         none     own                     2
# 1                   2   22         none     own                     1
# 2                   3   49         none     own                     1
# 3                   4   45         none   other                     1
# 4                   4   53         none   other                     2
#
#          job  dependents phone default
# 0    skilled           1   yes      no
# 1    skilled           1    no     yes
# 2  unskilled           2    no      no
# 3    skilled           2    no      no
# 4    skilled           2    no     yes

# %%
df.isnull().sum()
# Out:
# checking_balance        0
# months_loan_duration    0
# credit_history          0
# purpose                 0
# amount                  0
# savings_balance         0
# employment_duration     0
# percent_of_income       0
# years_at_residence      0
# age                     0
# other_credit            0
# housing                 0
# existing_loans_count    0
# job                     0
# dependents              0
# phone                   0
# default                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   checking_balance      1000 non-null   object
#  1   months_loan_duration  1000 non-null   int64
#  2   credit_history        1000 non-null   object
#  3   purpose               1000 non-null   object
#  4   amount                1000 non-null   int64
#  5   savings_balance       1000 non-null   object
#  6   employment_duration   1000 non-null   object
#  7   percent_of_income     1000 non-null   int64
#  8   years_at_residence    1000 non-null   int64
#  9   age                   1000 non-null   int64
#  10  other_credit          1000 non-null   object
#  11  housing               1000 non-null   object
#  12  existing_loans_count  1000 non-null   int64
#  13  job                   1000 non-null   object
#  14  dependents            1000 non-null   int64
#  15  phone                 1000 non-null   object
#  16  default               1000 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 132.9+ KB

# %%
Cat=[]
Num=[]

# %%
for i in df.drop('default',axis=1,inplace=False).columns:
    if(df[i].dtype=="object"):
        Cat.append(i)
    else:
        Num.append(i)

# %%
Num
# Out:
# ['months_loan_duration',
#  'amount',
#  'percent_of_income',
#  'years_at_residence',
#  'age',
#  'existing_loans_count',
#  'dependents']

# %%
Cat
# Out:
# ['checking_balance',
#  'credit_history',
#  'purpose',
#  'savings_balance',
#  'employment_duration',
#  'other_credit',
#  'housing',
#  'job',
#  'phone']

# %%
for i in Cat:
    print(df[i].value_counts())
    print()
# Out:
# checking_balance
# unknown       394
# < 0 DM        274
# 1 - 200 DM    269
# > 200 DM       63
# Name: count, dtype: int64
#
# credit_history
# good         530
# critical     293
# poor          88
# very good     49
# perfect       40
# Name: count, dtype: int64
#
# purpose
# furniture/appliances    473
# car                     337
# business                 97
# education                59
# renovations              22
# car0                     12
# Name: count, dtype: int64
#
# savings_balance
# < 100 DM         603
# unknown          183
# 100 - 500 DM     103
# 500 - 1000 DM     63
# > 1000 DM         48
# Name: count, dtype: int64
#
# employment_duration
# 1 - 4 years    339
# > 7 years      253
# 4 - 7 years    174
# < 1 year       172
# unemployed      62
# Name: count, dtype: int64
#
# other_credit
# none     814
# bank     139
# store     47
# Name: count, dtype: int64
#
# housing
# own      713
# rent     179
# other    108
# Name: count, dtype: int64
#
# job
# skilled       630
# unskilled     200
# management    148
# unemployed     22
# Name: count, dtype: int64
#
# phone
# no     596
# yes    404
# Name: count, dtype: int64

# %%
df['purpose'].replace("car0","car",inplace=True)

# %%
for i in Cat:
    print(df[i].value_counts(normalize=True)) #normalize=True  will give freq in percent
    print()
# Out:
# checking_balance
# unknown       0.394
# < 0 DM        0.274
# 1 - 200 DM    0.269
# > 200 DM      0.063
# Name: proportion, dtype: float64
#
# credit_history
# good         0.530
# critical     0.293
# poor         0.088
# very good    0.049
# perfect      0.040
# Name: proportion, dtype: float64
#
# purpose
# furniture/appliances    0.473
# car                     0.349
# business                0.097
# education               0.059
# renovations             0.022
# Name: proportion, dtype: float64
#
# savings_balance
# < 100 DM         0.603
# unknown          0.183
# 100 - 500 DM     0.103
# 500 - 1000 DM    0.063
# > 1000 DM        0.048
# Name: proportion, dtype: float64
#
# employment_duration
# 1 - 4 years    0.339
# > 7 years      0.253
# 4 - 7 years    0.174
# < 1 year       0.172
# unemployed     0.062
# Name: proportion, dtype: float64
#
# other_credit
# none     0.814
# bank     0.139
# store    0.047
# Name: proportion, dtype: float64
#
# housing
# own      0.713
# rent     0.179
# other    0.108
# Name: proportion, dtype: float64
#
# job
# skilled       0.630
# unskilled     0.200
# management    0.148
# unemployed    0.022
# Name: proportion, dtype: float64
#
# phone
# no     0.596
# yes    0.404
# Name: proportion, dtype: float64

# %%
data=df.copy()

# %%
df_encoded=pd.get_dummies(df,columns=Cat,drop_first=False)

# %%
df_encoded
# Out:
#      months_loan_duration  amount  percent_of_income  years_at_residence  age  \
# 0                       6    1169                  4                   4   67
# 1                      48    5951                  2                   2   22
# 2                      12    2096                  2                   3   49
# 3                      42    7882                  2                   4   45
# 4                      24    4870                  3                   4   53
# ..                    ...     ...                ...                 ...  ...
# 995                    12    1736                  3                   4   31
# 996                    30    3857                  4                   4   40
# 997                    12     804                  4                   4   38
# 998                    45    1845                  4                   4   23
# 999                    45    4576                  3                   4   27
#
#      existing_loans_count  dependents default  checking_balance_1 - 200 DM  \
# 0                       2           1      no                        False
# 1                       1           1     yes                         True
# 2                       1           2      no                        False
# 3                       1           2      no                        False
# 4                       2           2     yes                        False
# ..                    ...         ...     ...                          ...
# 995                     1           1      no                        False
# 996                     1           1      no                        False
# 997                     1           1      no                        False
# 998                     1           1     yes                        False
# 999                     1           1      no                         True
#
#      checking_balance_< 0 DM  checking_balance_> 200 DM  \
# 0                       True                      False
# 1                      False                      False
# 2                      False                      False
# 3                       True                      False
# 4                       True                      False
# ..                       ...                        ...
# 995                    False                      False
# 996                     True                      False
# 997                    False                      False
# 998                     True                      False
# 999                    False                      False
#
#      checking_balance_unknown  credit_history_critical  credit_history_good  \
# 0                       False                     True                False
# 1                       False                    False                 True
# 2                        True                     True                False
# 3                       False                    False                 True
# 4                       False                    False                False
# ..                        ...                      ...                  ...
# 995                      True                    False                 True
# 996                     False                    False                 True
# 997                      True                    False                 True
# 998                     False                    False                 True
# 999                     False                     True                False
#
#      credit_history_perfect  credit_history_poor  credit_history_very good  \
# 0                     False                False                     False
# 1                     False                False                     False
# 2                     False                False                     False
# 3                     False                False                     False
# 4                     False                 True                     False
# ..                      ...                  ...                       ...
# 995                   False                False                     False
# 996                   False                False                     False
# 997                   False                False                     False
# 998                   False                False                     False
# 999                   False                False                     False
#
#      purpose_business  purpose_car  purpose_education  \
# 0               False        False              False
# 1               False        False              False
# 2               False        False               True
# 3               False        False              False
# 4               False         True              False
# ..                ...          ...                ...
# 995             False        False              False
# 996             False         True              False
# 997             False        False              False
# 998             False        False              False
# 999             False         True              False
#
#      purpose_furniture/appliances  purpose_renovations  \
# 0                            True                False
# 1                            True                False
# 2                           False                False
# 3                            True                False
# 4                           False                False
# ..                            ...                  ...
# 995                          True                False
# 996                         False                False
# 997                          True                False
# 998                          True                False
# 999                         False                False
#
#      savings_balance_100 - 500 DM  savings_balance_500 - 1000 DM  \
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                          False
# 4                           False                          False
# ..                            ...                            ...
# 995                         False                          False
# 996                         False                          False
# 997                         False                          False
# 998                         False                          False
# 999                          True                          False
#
#      savings_balance_< 100 DM  savings_balance_> 1000 DM  \
# 0                       False                      False
# 1                        True                      False
# 2                        True                      False
# 3                        True                      False
# 4                        True                      False
# ..                        ...                        ...
# 995                      True                      False
# 996                      True                      False
# 997                      True                      False
# 998                      True                      False
# 999                     False                      False
#
#      savings_balance_unknown  employment_duration_1 - 4 years  \
# 0                       True                            False
# 1                      False                             True
# 2                      False                            False
# 3                      False                            False
# 4                      False                             True
# ..                       ...                              ...
# 995                    False                            False
# 996                    False                             True
# 997                    False                            False
# 998                    False                             True
# 999                    False                            False
#
#      employment_duration_4 - 7 years  employment_duration_< 1 year  \
# 0                              False                         False
# 1                              False                         False
# 2                               True                         False
# 3                               True                         False
# 4                              False                         False
# ..                               ...                           ...
# 995                             True                         False
# 996                            False                         False
# 997                            False                         False
# 998                            False                         False
# 999                            False                         False
#
#      employment_duration_> 7 years  employment_duration_unemployed  \
# 0                             True                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ..                             ...                             ...
# 995                          False                           False
# 996                          False                           False
# 997                           True                           False
# 998                          False                           False
# 999                          False                            True
#
#      other_credit_bank  other_credit_none  other_credit_store  housing_other  \
# 0                False               True               False          False
# 1                False               True               False          False
# 2                False               True               False          False
# 3                False               True               False           True
# 4                False               True               False           True
# ..                 ...                ...                 ...            ...
# 995              False               True               False          False
# 996              False               True               False          False
# 997              False               True               False          False
# 998              False               True               False           True
# 999              False               True               False          False
#
#      housing_own  housing_rent  job_management  job_skilled  job_unemployed  \
# 0           True         False           False         True           False
# 1           True         False           False         True           False
# 2           True         False           False        False           False
# 3          False         False           False         True           False
# 4          False         False           False         True           False
# ..           ...           ...             ...          ...             ...
# 995         True         False           False        False           False
# 996         True         False            True        False           False
# 997         True         False           False         True           False
# 998        False         False           False         True           False
# 999         True         False           False         True           False
#
#      job_unskilled  phone_no  phone_yes
# 0            False     False       True
# 1            False      True      False
# 2             True      True      False
# 3            False      True      False
# 4            False      True      False
# ..             ...       ...        ...
# 995           True      True      False
# 996          False     False       True
# 997          False      True      False
# 998          False     False       True
# 999          False      True      False
#
# [1000 rows x 44 columns]

# %%
pd.set_option('display.max_columns',None)

# %%
df_encoded.head()
# Out:
#    months_loan_duration  amount  percent_of_income  years_at_residence  age  \
# 0                     6    1169                  4                   4   67
# 1                    48    5951                  2                   2   22
# 2                    12    2096                  2                   3   49
# 3                    42    7882                  2                   4   45
# 4                    24    4870                  3                   4   53
#
#    existing_loans_count  dependents default  checking_balance_1 - 200 DM  \
# 0                     2           1      no                        False
# 1                     1           1     yes                         True
# 2                     1           2      no                        False
# 3                     1           2      no                        False
# 4                     2           2     yes                        False
#
#    checking_balance_< 0 DM  checking_balance_> 200 DM  \
# 0                     True                      False
# 1                    False                      False
# 2                    False                      False
# 3                     True                      False
# 4                     True                      False
#
#    checking_balance_unknown  credit_history_critical  credit_history_good  \
# 0                     False                     True                False
# 1                     False                    False                 True
# 2                      True                     True                False
# 3                     False                    False                 True
# 4                     False                    False                False
#
#    credit_history_perfect  credit_history_poor  credit_history_very good  \
# 0                   False                False                     False
# 1                   False                False                     False
# 2                   False                False                     False
# 3                   False                False                     False
# 4                   False                 True                     False
#
#    purpose_business  purpose_car  purpose_education  \
# 0             False        False              False
# 1             False        False              False
# 2             False        False               True
# 3             False        False              False
# 4             False         True              False
#
#    purpose_furniture/appliances  purpose_renovations  \
# 0                          True                False
# 1                          True                False
# 2                         False                False
# 3                          True                False
# 4                         False                False
#
#    savings_balance_100 - 500 DM  savings_balance_500 - 1000 DM  \
# 0                         False                          False
# 1                         False                          False
# 2                         False                          False
# 3                         False                          False
# 4                         False                          False
#
#    savings_balance_< 100 DM  savings_balance_> 1000 DM  \
# 0                     False                      False
# 1                      True                      False
# 2                      True                      False
# 3                      True                      False
# 4                      True                      False
#
#    savings_balance_unknown  employment_duration_1 - 4 years  \
# 0                     True                            False
# 1                    False                             True
# 2                    False                            False
# 3                    False                            False
# 4                    False                             True
#
#    employment_duration_4 - 7 years  employment_duration_< 1 year  \
# 0                            False                         False
# 1                            False                         False
# 2                             True                         False
# 3                             True                         False
# 4                            False                         False
#
#    employment_duration_> 7 years  employment_duration_unemployed  \
# 0                           True                           False
# 1                          False                           False
# 2                          False                           False
# 3                          False                           False
# 4                          False                           False
#
#    other_credit_bank  other_credit_none  other_credit_store  housing_other  \
# 0              False               True               False          False
# 1              False               True               False          False
# 2              False               True               False          False
# 3              False               True               False           True
# 4              False               True               False           True
#
#    housing_own  housing_rent  job_management  job_skilled  job_unemployed  \
# 0         True         False           False         True           False
# 1         True         False           False         True           False
# 2         True         False           False        False           False
# 3        False         False           False         True           False
# 4        False         False           False         True           False
#
#    job_unskilled  phone_no  phone_yes
# 0          False     False       True
# 1          False      True      False
# 2           True      True      False
# 3          False      True      False
# 4          False      True      False

# %%
df_encoded['default'].replace(['no','yes'],value=[0,1],inplace=True)

# %% [markdown]
# Test_Trin Split

# %%
X=df_encoded.drop("default",axis=1)
y=df_encoded[["default"]]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=1)

# %%
X_train.shape
# Out:
# (750, 43)

# %% [markdown]
# #### Building dt model

# %%
dt_model=DecisionTreeClassifier()

# %%
dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
def evaluate_train_model(model):
    y_train_predict = model.predict(X_train)

    Acc_train = print(model.score(X_train,y_train))

    CM_train = print(sns.heatmap((metrics.confusion_matrix(y_train,y_train_predict)),annot=True,fmt='.5g'
                ,cmap='Blues'));
    plt.xlabel('Predicted');
    plt.ylabel('Actuals',rotation=0);
    plt.title('CONFUSION MATRIX - CUT OFF (0.5)')

    CR_train = print(metrics.classification_report(y_train,y_train_predict))

    probs = model.predict_proba(X_train)
    probs = probs[:, 1]
    auc_train = roc_auc_score(y_train, probs)
    
    return Acc_train,CM_train,CR_train,auc_train

# %%
def evaluate_test_model(model):
    y_test_predict = model.predict(X_test)

    Acc_test = print("The accuracy of the model is {}".format(model.score(X_test,y_test)))

    CM_test = print(sns.heatmap((metrics.confusion_matrix(y_test,y_test_predict)),annot=True,fmt='.5g'
                ,cmap='Blues'));
    plt.xlabel('Predicted');
    plt.ylabel('Actuals',rotation=0);
    plt.title('CONFUSION MATRIX - CUT OFF (0.5)')

    CR_test = print(metrics.classification_report(y_test,y_test_predict))

    probs = model.predict_proba(X_test)
    probs = probs[:, 1]
    auc_test = roc_auc_score(y_test, probs)
    
    return Acc_test,CM_test,CR_test,auc_test

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
evaluate_train_model(dt_model)
# Out:
# 1.0
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       524
#            1       1.00      1.00      1.00       226
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750
# (None, None, None, 1.0)

# %%
evaluate_test_model(dt_model)
# Out:
# The accuracy of the model is 0.66
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.76       176
#            1       0.42      0.36      0.39        74
#
#     accuracy                           0.66       250
#    macro avg       0.58      0.57      0.58       250
# weighted avg       0.65      0.66      0.65       250
# (None, None, None, 0.574477886977887)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
plt.figure(figsize=(12, 8))
plot_tree(dt_model, feature_names=X.columns, class_names=["Default_Yes", "Default_No"], filled=True)
plt.show()

# %% [markdown]
# Variable Importance

# %%
pd.DataFrame((dt_model.feature_importances_ * 100),index=X.columns).sort_values(by=0,ascending=False)
# Out:
#                                          0
# amount                           21.867715
# months_loan_duration             11.616328
# checking_balance_unknown         10.103475
# age                               7.886748
# percent_of_income                 4.050573
# employment_duration_> 7 years     3.244267
# years_at_residence                3.151626
# purpose_car                       2.796145
# housing_other                     2.734981
# credit_history_critical           2.414118
# checking_balance_< 0 DM           2.253001
# purpose_business                  2.160477
# housing_own                       2.100503
# existing_loans_count              1.970989
# job_unskilled                     1.733667
# savings_balance_< 100 DM          1.688921
# other_credit_none                 1.667462
# credit_history_poor               1.433761
# job_skilled                       1.254321
# credit_history_good               1.185757
# phone_no                          1.182193
# savings_balance_unknown           1.161082
# credit_history_perfect            1.134162
# purpose_education                 1.068915
# employment_duration_4 - 7 years   1.059905
# savings_balance_> 1000 DM         1.036338
# job_management                    0.997197
# employment_duration_unemployed    0.933737
# employment_duration_1 - 4 years   0.738870
# employment_duration_< 1 year      0.699561
# phone_yes                         0.474988
# credit_history_very good          0.436646
# purpose_renovations               0.435432
# purpose_furniture/appliances      0.410226
# other_credit_store                0.337769
# savings_balance_500 - 1000 DM     0.237494
# housing_rent                      0.211106
# dependents                        0.129542
# other_credit_bank                 0.000000
# checking_balance_> 200 DM         0.000000
# job_unemployed                    0.000000
# checking_balance_1 - 200 DM       0.000000
# savings_balance_100 - 500 DM      0.000000

# %%
df_encoded.head()
# Out:
#    months_loan_duration  amount  percent_of_income  years_at_residence  age  \
# 0                     6    1169                  4                   4   67
# 1                    48    5951                  2                   2   22
# 2                    12    2096                  2                   3   49
# 3                    42    7882                  2                   4   45
# 4                    24    4870                  3                   4   53
#
#    existing_loans_count  dependents  default  checking_balance_1 - 200 DM  \
# 0                     2           1        0                        False
# 1                     1           1        1                         True
# 2                     1           2        0                        False
# 3                     1           2        0                        False
# 4                     2           2        1                        False
#
#    checking_balance_< 0 DM  checking_balance_> 200 DM  \
# 0                     True                      False
# 1                    False                      False
# 2                    False                      False
# 3                     True                      False
# 4                     True                      False
#
#    checking_balance_unknown  credit_history_critical  credit_history_good  \
# 0                     False                     True                False
# 1                     False                    False                 True
# 2                      True                     True                False
# 3                     False                    False                 True
# 4                     False                    False                False
#
#    credit_history_perfect  credit_history_poor  credit_history_very good  \
# 0                   False                False                     False
# 1                   False                False                     False
# 2                   False                False                     False
# 3                   False                False                     False
# 4                   False                 True                     False
#
#    purpose_business  purpose_car  purpose_education  \
# 0             False        False              False
# 1             False        False              False
# 2             False        False               True
# 3             False        False              False
# 4             False         True              False
#
#    purpose_furniture/appliances  purpose_renovations  \
# 0                          True                False
# 1                          True                False
# 2                         False                False
# 3                          True                False
# 4                         False                False
#
#    savings_balance_100 - 500 DM  savings_balance_500 - 1000 DM  \
# 0                         False                          False
# 1                         False                          False
# 2                         False                          False
# 3                         False                          False
# 4                         False                          False
#
#    savings_balance_< 100 DM  savings_balance_> 1000 DM  \
# 0                     False                      False
# 1                      True                      False
# 2                      True                      False
# 3                      True                      False
# 4                      True                      False
#
#    savings_balance_unknown  employment_duration_1 - 4 years  \
# 0                     True                            False
# 1                    False                             True
# 2                    False                            False
# 3                    False                            False
# 4                    False                             True
#
#    employment_duration_4 - 7 years  employment_duration_< 1 year  \
# 0                            False                         False
# 1                            False                         False
# 2                             True                         False
# 3                             True                         False
# 4                            False                         False
#
#    employment_duration_> 7 years  employment_duration_unemployed  \
# 0                           True                           False
# 1                          False                           False
# 2                          False                           False
# 3                          False                           False
# 4                          False                           False
#
#    other_credit_bank  other_credit_none  other_credit_store  housing_other  \
# 0              False               True               False          False
# 1              False               True               False          False
# 2              False               True               False          False
# 3              False               True               False           True
# 4              False               True               False           True
#
#    housing_own  housing_rent  job_management  job_skilled  job_unemployed  \
# 0         True         False           False         True           False
# 1         True         False           False         True           False
# 2         True         False           False        False           False
# 3        False         False           False         True           False
# 4        False         False           False         True           False
#
#    job_unskilled  phone_no  phone_yes
# 0          False     False       True
# 1          False      True      False
# 2           True      True      False
# 3          False      True      False
# 4          False      True      False

# %% [markdown]
# #### DT Pruning

# %%
dt_model_pru=DecisionTreeClassifier(criterion='gini',max_depth=7,min_samples_split=20,max_leaf_nodes=7)

# %%
dt_model_pru.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, max_leaf_nodes=7, min_samples_split=20)

# %%
evaluate_train_model(dt_model_pru)
# Out:
# 0.744
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#            0       0.74      0.98      0.84       524
#            1       0.84      0.19      0.30       226
#
#     accuracy                           0.74       750
#    macro avg       0.79      0.59      0.57       750
# weighted avg       0.77      0.74      0.68       750
# (None, None, None, 0.7395924812538)

# %%
evaluate_test_model(dt_model_pru)
# Out:
# The accuracy of the model is 0.736
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#            0       0.73      0.99      0.84       176
#            1       0.90      0.12      0.21        74
#
#     accuracy                           0.74       250
#    macro avg       0.81      0.56      0.53       250
# weighted avg       0.78      0.74      0.66       250
# (None, None, None, 0.7380605036855037)

# %%
dt_model_pru2=DecisionTreeClassifier(criterion='entropy',max_depth=7,min_samples_split=20,max_leaf_nodes=7)

# %%
dt_model_pru2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, max_leaf_nodes=7,
#                        min_samples_split=20)

# %%
evaluate_train_model(dt_model_pru2)
# Out:
# 0.7106666666666667
# Axes(0.125,0.1;0.62x0.8)
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83       524
#            1       1.00      0.04      0.08       226
#
#     accuracy                           0.71       750
#    macro avg       0.85      0.52      0.45       750
# weighted avg       0.80      0.71      0.60       750
# (None, None, None, 0.7369241032223198)

# %%
evaluate_test_model('dt_model_pru2')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 evaluate_test_model('dt_model_pru2')
#
# Cell In[156], line 2, in evaluate_test_model(model)
#       1 def evaluate_test_model(model):
# ----> 2     y_test_predict = model.predict(X_test)
#       4     Acc_test = print("The accuracy of the model is {}".format(model.score(X_test,y_test)))
#       6     CM_test = print(sns.heatmap((metrics.confusion_matrix(y_test,y_test_predict)),annot=True,fmt='.5g'
#       7                 ,cmap='Blues'));
#
# AttributeError: 'str' object has no attribute 'predict'
